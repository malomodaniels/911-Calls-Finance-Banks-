# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline
import seaborn as sns

# %%
import os
import pandas_datareader as pdr

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
#retrieving for Bank of America
BAC = data.DataReader('BAC', 'yahoo', start, end)
#retrieving for Bank of America
C = data.DataReader('C', 'yahoo', start, end)
#retrieving for Bank of America
GS = data.DataReader('GS', 'yahoo', start, end)
#retrieving for Bank of America
JPM = data.DataReader('JPM', 'yahoo', start, end)
#retrieving for Bank of America
MS = data.DataReader('MS', 'yahoo', start, end)
#retrieving for Bank of America
WFC = data.DataReader('WFC', 'yahoo', start, end)

# %%
 MS
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  37.140598
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  37.166069
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  37.267979
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  37.306194
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  37.701099
# ...               ...        ...        ...        ...        ...        ...
# 2015-12-24  32.709999  32.439999  32.570000  32.480000  2798200.0  28.914894
# 2015-12-28  32.360001  31.950001  32.360001  32.169998  5420300.0  28.638926
# 2015-12-29  32.700001  32.330002  32.439999  32.549999  6388200.0  28.977213
# 2015-12-30  32.650002  32.200001  32.500000  32.230000  5057200.0  28.692335
# 2015-12-31  32.299999  31.770000  31.910000  31.809999  8154300.0  28.318438
#
# [2517 rows x 6 columns]

# %%
#creating a list of ticker symbols (as strings) in alphabetical order

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
#concatenating columns
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys=tickers)

# %%
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.811729
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.442013
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.486385
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.434616
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.456806
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.749325
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.621654
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.758445
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.548695
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker', 'Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   34.811729  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   34.442013  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   34.486385  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
#for tick in tickers :
#    print(tick, bank_stocks[tick]['Close'].max())
bank_stocks.xs(key='Close', axis=1, level = 'Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers :
    returns[tick + 'Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158

# %%
sns.pairplot(returns[1:])

# %%
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158

# %%
returns.idxmin().head(6)
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax().head(6)
# Out:
# BACReturn   2009-04-09
# CReturn     2008-11-24
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
returns.loc['2015-01-01':'2015-01-31'].std().head(6)
# Out:
# BACReturn    0.022236
# CReturn      0.019371
# GSReturn     0.016121
# JPMReturn    0.019032
# MSReturn     0.015992
# WFCReturn    0.015449
# dtype: float64

# %%
sns.distplot(returns.loc['2015']['MSReturn'], color='green', bins=50)

# %%
sns.distplot(returns.loc['2008']['CReturn'], color='green', bins=50)

# %%
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="de05bb67-9ede-4bfb-8218-c37dd19e0a52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("de05bb67-9ede-4bfb-8218-c37dd19e0a52")) {
#                     Plotly.newPlot(
#                         'de05bb67-9ede-4bfb-8218-c37dd19e0a52',
# ...

# %%
for tick in tickers :
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
plt.legend()

# %%
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.811729
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.442013
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.486385
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.434616
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.456806

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01' : '2009-01-01'].rolling(window=30).mean().plot(label = '30 day moving average')
BAC['Close'].loc['2008-01-01' : '2009-01-01'].plot(label='BAC Close')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %%
Close_Corr = bank_stocks.xs(key='Close', axis=1, level='Stock Info')

# %%
Close_Corr.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="bf858616-f678-471d-adf8-576a40a4c880" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bf858616-f678-471d-adf8-576a40a4c880")) {
#                     Plotly.newPlot(
#                         'bf858616-f678-471d-adf8-576a40a4c880',
# ...

# %%
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.811729
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.442013
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.486385
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.434616
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.456806

# %%
BAC_2015 = BAC.loc['2015-01-01':'2016-01-01']

# %%
BAC_2015.iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="2f38c491-d5d1-400a-9e00-33d99a831496" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2f38c491-d5d1-400a-9e00-33d99a831496")) {
#                     Plotly.newPlot(
#                         '2f38c491-d5d1-400a-9e00-33d99a831496',
# ...

# %%
bank_stocks.loc()
